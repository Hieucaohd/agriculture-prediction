# %%
from proj.tasks import read_image_spectral, push_img_data_to_redis, push_img_data_to_redis_task
import redis
import numpy as np

# %%
img = read_image_spectral()
NUM_ROW, NUM_COL, NUM_BAND = img.shape

# %%
NUM_COL
# Out:
# 5287

# %%
# redis_conn = redis.Redis("localhost", 6379, db=3)
# push_img_data_to_redis(
# 	img,
# 	0,
# 	0,
# 	NUM_ROW,
#     redis_conn
# )

# %%
# for col in range(0, 100):
#     if col % 100 == 0:
#         print(col)
    
#     push_img_data_to_redis_task.delay(
#         col,
#         0,
#         NUM_ROW
#     )

# %%
# img_data_np = img[:, :, :]

# %%
# img_data_list = img_data_np.tolist()

# %%
a = np.array([
	[[1, 2], [3, 4], [5, 6]],
	[[1, 2], [3, 4], [5, 6]],
	[[1, 2], [3, 4], [5, 6]],
])

# %%
a_list = a.tolist()

# %%
a_str = str(a_list)

# %%
a_list_back = eval(a_str)

# %%
a_back = np.array(a_list_back)

# %%
a_back
# Out:
# array([[[1, 2],
#         [3, 4],
#         [5, 6]],
#
#        [[1, 2],
#         [3, 4],
#         [5, 6]],
#
#        [[1, 2],
#         [3, 4],
#         [5, 6]]])

# %%
a == a_back
# Out:
# array([[[ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True]]])

# %%
col_0_1000 = img[:, 0:1000, :]

# %%
col_0_1000_list = col_0_1000.tolist()
