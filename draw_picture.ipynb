# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'assigned_values' is your array with assigned values for each pixel
# Replace this with your actual data
assigned_values = np.random.randint(0, 255, size=(100, 100))

# Define a colormap (you can choose any colormap from matplotlib)
cmap = 'viridis'

# Create a figure and axis
fig, ax = plt.subplots()

# Display the image with the assigned colors
im = ax.imshow(assigned_values, cmap=cmap)

# Add a colorbar to the right of the plot
cbar = fig.colorbar(im, ax=ax)

# Show the plot
plt.show()

# %%
assigned_values
# Out:
# array([[ 77, 210,  27, ..., 101, 207, 168],
#        [122, 141, 196, ..., 139, 169, 241],
#        [229, 141,  54, ..., 181,  84,  42],
#        ...,
#        [169,  31,  97, ..., 120,  87, 232],
#        [123, 219, 135, ...,  11,  36, 133],
#        [121, 178, 100, ..., 245, 173, 127]])
